# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51528/COMPITATIVE_PROGRAMMING_1528/blob/main/week_2_backtracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonacci(n, memo):
    # Base cases
    if n == 0:
        return 0
    if n == 1:
        return 1

    if n in memo:
        return memo[n]

    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]

n = int(input())

memo = {}

result = fibonacci(n, memo)
print(result)
# Out:
# 10
# 55
